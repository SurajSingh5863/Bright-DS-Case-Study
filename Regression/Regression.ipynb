# %% [markdown]
# 1)	Thunder Basin Antelope Study
#
# The data (X1, X2, X3, X4) are for each year.</br>
# X1 = spring fawn count/100</br>
# X2 = size of adult antelope population/100</br>
# X3 = annual precipitation (inches)</br>
# X4 = winter severity index (1=mild,5=severe)

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('mlr01.csv', names=['X1', 'X2', 'X3', 'X4'], skiprows=[0])

# %%
plt.scatter(data['X1'],data['X3'])
plt.xlabel('Spring Fawn Count/100')
plt.ylabel('Annual Precipitation (inches)')
plt.show()

# %%
plt.scatter(data['X2'],data['X3'])
plt.xlabel('Size of adult antelope population/100')
plt.ylabel('Annual Precipitation (inches)')
plt.show()

# %%
plt.scatter(data['X4'],data['X3'])
plt.xlabel('Winter severity index (1=mild,5=severe)')
plt.ylabel('Annual Precipitation (inches)')
plt.show()

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(data[], y, test_size = 0.2, random_state = 0)

# %%
x_test
# Out:
# array([[ 9.69999981, 14.10000038,  1.        ],
#        [ 7.19999981, 10.80000019,  4.        ]])

# %%
x_train
# Out:
# array([[ 8.69999981, 11.5       ,  3.        ],
#        [ 7.9000001 , 11.19999981,  3.        ],
#        [ 8.5       , 12.30000019,  2.        ],
#        [ 9.19999981, 13.19999981,  2.        ],
#        [ 6.80000019, 10.60000038,  5.        ],
#        [ 9.6       , 12.60000038,  3.        ]])

# %%
# Training the Multiple Linear Regression model on the Training set
from sklearn.linear_model import LinearRegression
regressor = LinearRegression()
regressor.fit(x_train, y_train)


print("\nAccuracy of the model:")
print('\nTrain Score: ', regressor.score(x_train, y_train))  
print('\nTest Score: ', regressor.score(x_test, y_test))
# Out:
# Accuracy of the model:
#
# Train Score:  0.9905627528242525
#
# Test Score:  0.89461931199605

# %%
# prediction
y_pred = regressor.predict(X_test)

print("\n X_test: \n ")
print(X_test)
print("\n y_pred: \n ")
print(y_pred)
# Out:
#  X_test:
#
# [[ 7.9000001  11.19999981  3.        ]
#  [ 7.19999981 10.80000019  4.        ]]
#
#  y_pred:
#
# [2.02389045 1.87483315]

# %%
# just to see relationship

# Visualising the Training set results
fig=plt.figure(figsize=[7,5])
x1=np.array(x_train[:,2])
y1=np.array(y_train)

print("x1=",x1," len =", len(x1))
print("y1=",y1," len =", len(y1))
plt.scatter(x1,y1, color = 'red')


#print("X_train=", X_train)
#print("Y=",y)

y_pred = regressor.predict(X_test)
x1=np.array(x_test[:,2])

plt.plot(x1, y_pred, "s-", markerfacecolor="yellow", markersize="10")
# Out:
# x1= [3. 3. 2. 2. 5. 3.]  len = 6
# y1= [2.4000001  2.0999999  2.29999995 2.9000001  1.89999998 3.20000005]  len = 6

# %%
data.loc['X1', 'X2','X4']
# Out:
# ---------------------------------------------------------------------------
# IndexingError                             Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_8436/3666968327.py in <module>
# ----> 1 data.loc['X1', 'X2','X4']
#
# ~\anaconda3\envs\tensorflow\lib\site-packages\pandas\core\indexing.py in __getitem__(self, key)
#     923                 with suppress(KeyError, IndexError):
#     924                     return self.obj._get_value(*key, takeable=self._takeable)
# --> 925             return self._getitem_tuple(key)
#     926         else:
#     927             # we by definition only have the 0th axis
#
# ~\anaconda3\envs\tensorflow\lib\site-packages\pandas\core\indexing.py in _getitem_tuple(self, tup)
#    1101
#    1102         # no multi-index, so validate all of the indexers
# -> 1103         self._has_valid_tuple(tup)
#    1104
#    1105         # ugly hack for GH #836
#
# ...
